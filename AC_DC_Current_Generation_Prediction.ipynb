# %% [markdown]
# <a href="https://colab.research.google.com/github/shsaniya04/Machine-Learning-Projects/blob/main/AC_DC_Current_Generation_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORTING LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the dataset
gd = pd.read_csv('/content/Generation_Data.csv')
wd = pd.read_csv('/content/Weather_Sensor_Data.csv')

# %%
gd
# Out:
#                  DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0      2020-05-15 00:00:00   4136001  4UPUqMRk7TRMgml       0.0       0.0
# 1      2020-05-15 00:00:00   4136001  81aHJ1q11NBPMrL       0.0       0.0
# 2      2020-05-15 00:00:00   4136001  9kRcWv60rDACzjR       0.0       0.0
# 3      2020-05-15 00:00:00   4136001  Et9kgGMDl729KT4       0.0       0.0
# 4      2020-05-15 00:00:00   4136001  IQ2d7wF4YD8zU1Q       0.0       0.0
# ...                    ...       ...              ...       ...       ...
# 67693  2020-06-17 23:45:00   4136001  q49J1IKaHRwDQnt       0.0       0.0
# 67694  2020-06-17 23:45:00   4136001  rrq4fwE8jgrTyWY       0.0       0.0
# 67695  2020-06-17 23:45:00   4136001  vOuJvMaM2sgwLmb       0.0       0.0
# 67696  2020-06-17 23:45:00   4136001  xMbIugepa2P7lBB       0.0       0.0
# 67697  2020-06-17 23:45:00   4136001  xoJJ8DcxJEcupym       0.0       0.0
#
#        DAILY_YIELD   TOTAL_YIELD
# 0      9425.000000  2.429011e+06
# ...

# %%
wd
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 0     2020-05-15 00:00:00   4136001  iq8k7ZNt4Mwm3w0            27.004764
# 1     2020-05-15 00:15:00   4136001  iq8k7ZNt4Mwm3w0            26.880811
# 2     2020-05-15 00:30:00   4136001  iq8k7ZNt4Mwm3w0            26.682055
# 3     2020-05-15 00:45:00   4136001  iq8k7ZNt4Mwm3w0            26.500589
# 4     2020-05-15 01:00:00   4136001  iq8k7ZNt4Mwm3w0            26.596148
# ...                   ...       ...              ...                  ...
# 3254  2020-06-17 22:45:00   4136001  iq8k7ZNt4Mwm3w0            23.511703
# 3255  2020-06-17 23:00:00   4136001  iq8k7ZNt4Mwm3w0            23.482282
# 3256  2020-06-17 23:15:00   4136001  iq8k7ZNt4Mwm3w0            23.354743
# 3257  2020-06-17 23:30:00   4136001  iq8k7ZNt4Mwm3w0            23.291048
# 3258  2020-06-17 23:45:00   4136001  iq8k7ZNt4Mwm3w0            23.202871
#
#       MODULE_TEMPERATURE  IRRADIATION
# 0              25.060789          0.0
# ...

# %%
gd.sample(5)
# Out:
#                  DATE_TIME  PLANT_ID       SOURCE_KEY    DC_POWER    AC_POWER  \
# 37923  2020-06-03 21:30:00   4136001  WcxssY2VbP4hApt    0.000000    0.000000
# 62184  2020-06-15 09:15:00   4136001  NgDl19wMapZy17u  769.253333  752.486667
# 39080  2020-06-04 10:45:00   4136001  IQ2d7wF4YD8zU1Q  468.493333  459.653333
# 36668  2020-06-03 07:00:00   4136001  V94E5Ben1TlhnDV  153.793333  150.260000
# 8173   2020-05-18 21:00:00   4136001  Quc1TzYxW2pYoWX    0.000000    0.000000
#
#        DAILY_YIELD   TOTAL_YIELD
# 37923  5691.000000  1.818440e+08
# 62184  1239.066667  1.117311e+08
# 39080  2142.000000  2.009770e+07
# 36668    65.266667  1.412223e+09
# 8173   2787.000000  3.295260e+08

# %%
gd.head()
# Out:
#              DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  AC_POWER  \
# 0  2020-05-15 00:00:00   4136001  4UPUqMRk7TRMgml       0.0       0.0
# 1  2020-05-15 00:00:00   4136001  81aHJ1q11NBPMrL       0.0       0.0
# 2  2020-05-15 00:00:00   4136001  9kRcWv60rDACzjR       0.0       0.0
# 3  2020-05-15 00:00:00   4136001  Et9kgGMDl729KT4       0.0       0.0
# 4  2020-05-15 00:00:00   4136001  IQ2d7wF4YD8zU1Q       0.0       0.0
#
#    DAILY_YIELD   TOTAL_YIELD
# 0  9425.000000  2.429011e+06
# 1     0.000000  1.215279e+09
# 2  3075.333333  2.247720e+09
# 3   269.933333  1.704250e+06
# 4  3177.000000  1.994153e+07

# %%
wd.sample(5)
# Out:
#                 DATE_TIME  PLANT_ID       SOURCE_KEY  AMBIENT_TEMPERATURE  \
# 2286  2020-06-07 20:45:00   4136001  iq8k7ZNt4Mwm3w0            26.817372
# 2896  2020-06-14 05:15:00   4136001  iq8k7ZNt4Mwm3w0            23.917826
# 3016  2020-06-15 11:15:00   4136001  iq8k7ZNt4Mwm3w0            30.406593
# 822   2020-05-23 14:00:00   4136001  iq8k7ZNt4Mwm3w0            37.342486
# 1516  2020-05-30 19:45:00   4136001  iq8k7ZNt4Mwm3w0            31.743003
#
#       MODULE_TEMPERATURE  IRRADIATION
# 2286           25.502152     0.000000
# 2896           23.409377     0.000000
# 3016           40.686538     0.663464
# 822            58.355512     0.815193
# 1516           29.323393     0.000000

# %%
gd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67698 entries, 0 to 67697
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE_TIME    67698 non-null  object
#  1   PLANT_ID     67698 non-null  int64
#  2   SOURCE_KEY   67698 non-null  object
#  3   DC_POWER     67698 non-null  float64
#  4   AC_POWER     67698 non-null  float64
#  5   DAILY_YIELD  67698 non-null  float64
#  6   TOTAL_YIELD  67698 non-null  float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 3.6+ MB

# %%
wd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3259 entries, 0 to 3258
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            3259 non-null   object
#  1   PLANT_ID             3259 non-null   int64
#  2   SOURCE_KEY           3259 non-null   object
#  3   AMBIENT_TEMPERATURE  3259 non-null   float64
#  4   MODULE_TEMPERATURE   3259 non-null   float64
#  5   IRRADIATION          3259 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 152.9+ KB

# %%
gd['DATE_TIME'] = pd.to_datetime(gd['DATE_TIME'])
wd['DATE_TIME'] = pd.to_datetime(wd['DATE_TIME'])

# %%
df_solar = pd.merge(gd.drop(columns = ['PLANT_ID']), wd.drop(columns = ['PLANT_ID', 'SOURCE_KEY']), on='DATE_TIME')
df_solar.sample(5)
# Out:
#                 DATE_TIME       SOURCE_KEY     DC_POWER     AC_POWER  \
# 45728 2020-06-07 14:15:00  NgDl19wMapZy17u  1206.073333  1176.766667
# 8834  2020-05-19 04:30:00  V94E5Ben1TlhnDV     0.000000     0.000000
# 51640 2020-06-10 09:30:00  9kRcWv60rDACzjR  1017.420000   993.246667
# 45925 2020-06-07 16:30:00  Mx2yZCDsyf6DPfv   365.971429   359.242857
# 1084  2020-05-15 12:15:00  LlT2YUhhzqhg5Sw  1266.035714  1234.378571
#
#        DAILY_YIELD   TOTAL_YIELD  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# 45728  6103.800000  1.116894e+08            32.816685           50.005705
# 8834      0.000000  1.412111e+09            25.108053           23.989105
# 51640  1072.800000  2.247879e+09            28.454675           39.858438
# 45925  7426.642857  2.632539e+06            31.264936           36.138931
# 1084   4883.857143  2.825977e+08            36.377571           57.588582
#
#        IRRADIATION
# 45728     0.739974
# 8834      0.000000
# 51640     0.702594
# 45925     0.228878
# ...

# %%
df_solar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67698 entries, 0 to 67697
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            67698 non-null  datetime64[ns]
#  1   SOURCE_KEY           67698 non-null  object
#  2   DC_POWER             67698 non-null  float64
#  3   AC_POWER             67698 non-null  float64
#  4   DAILY_YIELD          67698 non-null  float64
#  5   TOTAL_YIELD          67698 non-null  float64
#  6   AMBIENT_TEMPERATURE  67698 non-null  float64
#  7   MODULE_TEMPERATURE   67698 non-null  float64
#  8   IRRADIATION          67698 non-null  float64
# dtypes: datetime64[ns](1), float64(7), object(1)
# memory usage: 4.6+ MB

# %%
df_solar.isnull().sum()
# Out:
# DATE_TIME              0
# SOURCE_KEY             0
# DC_POWER               0
# AC_POWER               0
# DAILY_YIELD            0
# TOTAL_YIELD            0
# AMBIENT_TEMPERATURE    0
# MODULE_TEMPERATURE     0
# IRRADIATION            0
# dtype: int64

# %%
df_solar.describe().style.background_gradient(cmap = 'Blues')
# Out:
# <style type="text/css">
# #T_bfd90_row0_col1, #T_bfd90_row0_col2, #T_bfd90_row0_col3, #T_bfd90_row0_col5, #T_bfd90_row0_col6, #T_bfd90_row0_col7, #T_bfd90_row6_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_bfd90_row0_col4, #T_bfd90_row1_col1, #T_bfd90_row1_col2, #T_bfd90_row1_col5, #T_bfd90_row1_col6, #T_bfd90_row1_col7, #T_bfd90_row2_col1, #T_bfd90_row2_col2, #T_bfd90_row2_col3, #T_bfd90_row2_col4, #T_bfd90_row2_col5, #T_bfd90_row2_col6, #T_bfd90_row2_col7, #T_bfd90_row3_col1, #T_bfd90_row3_col2, #T_bfd90_row3_col5, #T_bfd90_row3_col6, #T_bfd90_row3_col7, #T_bfd90_row4_col1, #T_bfd90_row4_col2, #T_bfd90_row4_col5, #T_bfd90_row4_col6, #T_bfd90_row4_col7, #T_bfd90_row5_col5, #T_bfd90_row5_col6, #T_bfd90_row5_col7, #T_bfd90_row6_col5, #T_bfd90_row6_col6, #T_bfd90_row6_col7, #T_bfd90_row7_col5, #T_bfd90_row7_col6, #T_bfd90_row7_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_bfd90_row1_col3, #T_bfd90_row4_col3, #T_bfd90_row7_col3 {
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_solar['SOURCE_KEY'] = le.fit_transform(df_solar['SOURCE_KEY'])
df_solar.head()
# Out:
#    DATE_TIME  SOURCE_KEY  DC_POWER  AC_POWER  DAILY_YIELD   TOTAL_YIELD  \
# 0 2020-05-15           0       0.0       0.0  9425.000000  2.429011e+06
# 1 2020-05-15           1       0.0       0.0     0.000000  1.215279e+09
# 2 2020-05-15           2       0.0       0.0  3075.333333  2.247720e+09
# 3 2020-05-15           3       0.0       0.0   269.933333  1.704250e+06
# 4 2020-05-15           4       0.0       0.0  3177.000000  1.994153e+07
#
#    AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION
# 0            27.004764           25.060789          0.0
# 1            27.004764           25.060789          0.0
# 2            27.004764           25.060789          0.0
# 3            27.004764           25.060789          0.0
# 4            27.004764           25.060789          0.0

# %%
df_solar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67698 entries, 0 to 67697
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            67698 non-null  datetime64[ns]
#  1   SOURCE_KEY           67698 non-null  int64
#  2   DC_POWER             67698 non-null  float64
#  3   AC_POWER             67698 non-null  float64
#  4   DAILY_YIELD          67698 non-null  float64
#  5   TOTAL_YIELD          67698 non-null  float64
#  6   AMBIENT_TEMPERATURE  67698 non-null  float64
#  7   MODULE_TEMPERATURE   67698 non-null  float64
#  8   IRRADIATION          67698 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 4.6 MB

# %%
sns.displot(data=df_solar, x="AMBIENT_TEMPERATURE", kde=True, bins = 100,color = "red", facecolor = "#3F7F7F",height = 5, aspect = 3.5);

# %%
sns.displot(data=df_solar, x="MODULE_TEMPERATURE", kde=True, bins = 100,color = "red", facecolor = "#3F7F7F",height = 5, aspect = 3.5);
